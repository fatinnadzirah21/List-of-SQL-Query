# %% [markdown]
# <a href="https://colab.research.google.com/github/fatinnadzirah21/List-of-SQL-Query/blob/main/Airbnb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
airbnb = pd.read_csv("/content/drive/MyDrive/Datasets/Airbnb_NYC_2019_DATA_WRANGLING_3 - Airbnb NYC 2019.csv")
airbnb
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (10) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#              ID                                        Airbnb Name   Host ID  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# ...

# %%
airbnb.isna().sum()
# Out:
# ID                                0
# Airbnb Name                       0
# Host ID                           0
# Host Name                         0
# Neighbourhood Group               0
# Neighbourhood                     0
# Latitude                          0
# Longitude                         0
# Room Type                         0
# Price                             0
# Minimum Nights                    0
# Number of Reviews                 0
# Last Review                       0
# Reviews per Month                 0
# Calculated Host Listings Count    0
# Availability in A Year            0
# Clean                             0
# dtype: int64

# %%
airbnb['Airbnb Name'].fillna("NA", inplace=True)

# %%
airbnb_brooklyn = airbnb[airbnb['Neighbourhood Group'] == 'Brooklyn']
airbnb_brooklyn
# Out:
#              ID                                      Airbnb Name    Host ID  \
# 0          2539               Clean & quiet apt home by the park       2787
# 3          3831                  Cozy Entire Floor of Brownstone       4869
# 6          5121                                  BlissArtsSpace!       7356
# 12         5803   Lovely Room 1, Garden, Best Area, Legal rental       9744
# 15         6848                 Only 2 stops to Manhattan studio      15991
# ...         ...                                              ...        ...
# 48882  36482231                        Bushwick _ Myrtle-Wyckoff   66058896
# 48884  36482783      Brooklyn Oasis in the heart of Williamsburg  274307600
# 48887  36483152  Garden Jewel Apartment in Williamsburg New York  208514239
# 48890  36484665  Charming one bedroom - newly renovated rowhouse    8232441
# 48891  36485057    Affordable room in Bushwick/East Williamsburg    6570630
#
# ...

# %%
from google.colab import files
airbnb_brooklyn.to_csv("submission.csv", index=True) 
files.download("submission.csv")
